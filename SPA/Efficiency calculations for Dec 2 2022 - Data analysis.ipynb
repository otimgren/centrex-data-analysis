# %% [markdown]
# # Efficiency calculations for Dec 2 2022 - Data analysis
# Running the data analysis for the data from Dec 2 2021.
#
# Load the data analysis script:

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from SPA_camera_data_analysis import analyze_SPA_dataset

# Suppressing warnings if desired (getting annoying warning about run names)
import warnings
warnings.filterwarnings(action = 'ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Set up paths:

# %%
# Define path to data
DATA_DIR = Path(
    "G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Data"
)
DATA_FNAME = Path("SPA_test_12_2_2021.hdf")
filepath = DATA_DIR / DATA_FNAME

# %% [markdown]
# Define number of bootstraps:

# %%
n_bs = 1000

# %% [markdown]
# ## R(0), F' = 2, SPA1 switching

# %%
analyze_SPA_dataset(
    filepath,
    10,
    0,
    scan_param_name='SynthHD Pro SPA SetPowerCHAGUI',
    scan_param_new_name='SPAJ01Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 1.72 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 26.4min finished
# Saved bootstrapped results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_bootstrap.hdf
#
# Saved aggregated results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_analyzed.hdf
#
# Run name:
# 1638479291 R(0), F = 2 with SPA J = 0 to 1 microwaves switching

# %% [markdown]
# ## R(1), F' = 3, SPA1 switching

# %%
analyze_SPA_dataset(
    filepath,
    12,
    0,
    scan_param_name='SynthHD Pro SPA SetPowerCHAGUI',
    scan_param_new_name='SPAJ01Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 2.50 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 25.4min finished
# Saved bootstrapped results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_bootstrap.hdf
#
# Saved aggregated results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_analyzed.hdf
#
# Run name:
# 1638481381 R(1), F = 3 with SPA J = 0 to 1 microwaves switching

# %% [markdown]
# ## R(1), F' = 3, SPA1 on, SPA2 switching

# %%
analyze_SPA_dataset(
    filepath,
    15,
    0,
    scan_param_name='SynthHD Pro SPA J12 SetPowerCHAGUI',
    scan_param_new_name='SPAJ12Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 1.83 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 25.5min finished
# Saved bootstrapped results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_bootstrap.hdf
#
# Saved aggregated results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_analyzed.hdf
#
# Run name:
# 1638483736 R(1), F = 3 with SPA J = 1 to 2 microwaves switching

# %% [markdown]
# ## R(2), F' = 4, SPA1 on, SPA2 switching

# %%
analyze_SPA_dataset(
    filepath,
    17,
    0,
    scan_param_name='SynthHD Pro SPA J12 SetPowerCHAGUI',
    scan_param_new_name='SPAJ12Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 4.33 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 27.2min finished
# Saved bootstrapped results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_bootstrap.hdf
#
# Saved aggregated results to:
# G:\My Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_12_2_2021_analyzed.hdf
#
# Run name:
# 1638485119 R(2), F = 4 with SPA J = 1 to 2 microwaves switching
