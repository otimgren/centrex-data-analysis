# %% [markdown]
# # J = 1 to 2 parameter scans - Data analysis
# Running the data analysis for the data from Nov 9 2021 to for the parameter scans performed while observing the signal on R(1), F' = 3 and R(2), F' = 3. These scans give information about the optimal frequency and power for the second step of SPA.
#
# Load the data analysis script:

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from SPA_camera_data_analysis import analyze_SPA_dataset

# Suppressing warnings if desired (getting annoying warning about run names)
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# Set up paths:

# %%
# Define path to data
DATA_DIR = Path(
    "D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Data"
)
DATA_FNAME = Path("SPA_test_11_9_2021.hdf")
filepath = DATA_DIR / DATA_FNAME

# %% [markdown]
# Define number of bootstraps:

# %%
n_bs = 1000

# %% [markdown]
# ## R(1), F' = 3 frequency scan

# %%
analyze_SPA_dataset(
    filepath,
    16,
    0,
    scan_param_name='SynthHD Pro SPA J12 SetFrequencyCHAGUI',
    scan_param_new_name='SPAJ12Frequency',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 2.44 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.

# %% [markdown]
# ## R(1), F' = 3 power scan

# %%
analyze_SPA_dataset(
    filepath,
    17,
    0,
    scan_param_name= 'SynthHD Pro SPA J12 SetPowerCHAGUI',
    scan_param_new_name='SPAJ12Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1352
# Percentage of data cut: 2.86 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 53.3min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 96.0min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 121.5min finished
# Saved bootstrapped results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_bootstrap.hdf
#
# Saved aggregated results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_analyzed.hdf
#
# Run name:
# 1636499536 Depletion on R(1), F = 3, SPA J = 1 to 2 microwave power  scan

# %% [markdown]
# ## R(2), F' = 4 power scan

# %%
analyze_SPA_dataset(
    filepath,
    21,
    0,
    scan_param_name= 'SynthHD Pro SPA J12 SetPowerCHAGUI',
    scan_param_new_name='SPAJ12Power',
    switch_name = None,
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 5.07 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 35.9min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 64.4min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 81.4min finished
# Saved bootstrapped results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_bootstrap.hdf
#
# Saved aggregated results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_analyzed.hdf
#
# Run name:
# 1636502355 Accumulation on R(2), F = 4, SPA J = 1 to 2 microwave power scan

# %% [markdown]
# ## R(2), F' = 4 frequency scan

# %%
analyze_SPA_dataset(
    filepath,
    22,
    0,
    scan_param_name= 'SynthHD Pro SPA J12 SetFrequencyCHAGUI',
    scan_param_new_name='SPAJ12Frequency',
    switch_name = None,
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 1.45 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 60.7min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 107.2min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 135.1min finished
# Saved bootstrapped results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_bootstrap.hdf
#
# Saved aggregated results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_analyzed.hdf
#
# Run name:
# 1636503922 Accumulation on R(2), F = 4, SPA J = 1 to 2 microwave frequency scan
