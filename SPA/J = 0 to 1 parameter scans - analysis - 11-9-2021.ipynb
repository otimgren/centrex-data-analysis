# %% [markdown]
# # J = 0 to 1 parameter scans - Data analysis
# Running the data analysis for the data from Nov 9 2021 to for the parameter scans performed while observing the signal on R(0), F' = 2 and R(1), F' = 3. These scans give information about the optimal frequency and power for the first step of SPA.
#
# Load the data analysis script:

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from SPA_camera_data_analysis import analyze_SPA_dataset

# Suppressing warnings if desired (getting annoying warning about run names)
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# Set up paths:

# %%
# Define path to data
DATA_DIR = Path(
    "D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Data"
)
DATA_FNAME = Path("SPA_test_11_9_2021.hdf")
filepath = DATA_DIR / DATA_FNAME

# %% [markdown]
# Define number of bootstraps:

# %%
n_bs = 1000

# %% [markdown]
# ## R(0), F' = 2 frequency scan

# %%
analyze_SPA_dataset(
    filepath,
    6,
    0,
    scan_param_name='SynthHD Pro SPA SetFrequencyCHAGUI',
    scan_param_new_name='SPAJ01Frequency',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 5.39 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 35.7min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 87.7min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 160.5min

# %% [markdown]
# ## R(0), F' = 2 power scan

# %%
analyze_SPA_dataset(
    filepath,
    7,
    0,
    scan_param_name= 'SynthHD Pro SPA SetPowerCHAGUI',
    scan_param_new_name='SPAJ01Power',
    switch_name = 'MicrowavesON',
    n_bs = n_bs,
)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1353
# Percentage of data cut: 6.52 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.

# %% [markdown]
# ## R(1), F' = 3 power scan

# %%
analyze_SPA_dataset(
    filepath,
    12,
    0,
    scan_param_name= 'SynthHD Pro SPA SetPowerCHAGUI',
    scan_param_new_name='SPAJ01Power',
    switch_name = None,
    n_bs = n_bs,
)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1354
# Percentage of data cut: 6.18 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 35.7min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 64.5min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 81.9min finished
# Saved bootstrapped results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_bootstrap.hdf
#
# Saved aggregated results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_analyzed.hdf
#
# Run name:
# 1636492543 Accumulation on R(1), F = 3, SPA J = 0 to 1 microwave power scan

# %% [markdown]
# ## R(1), F' = 3 frequency scan

# %%
analyze_SPA_dataset(
    filepath,
    13,
    0,
    scan_param_name= 'SynthHD Pro SPA SetFrequencyCHAGUI',
    scan_param_new_name='SPAJ01Frequency',
    switch_name = None,
    n_bs = n_bs,
)
# Out:
# Percentage of data cut: 4.79 %
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 56.2min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 83.8min
# [Parallel(n_jobs=5)]: Done 1000 out of 1000 | elapsed: 98.5min finished
# Saved bootstrapped results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_bootstrap.hdf
#
# Saved aggregated results to:
# D:\Google Drive\CeNTREX Oskari\State preparation\SPA\Data analysis\Analyzed Data\SPA_test_11_9_2021_analyzed.hdf
#
# Run name:
# 1636493528 Accumulation on R(1), F = 3, SPA J = 0 to 1 microwave frequency scan
